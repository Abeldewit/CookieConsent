# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import ast

df = pd.read_csv('assets/DataFrame.csv', converters={"Host": ast.literal_eval,
                                                     "cookie_first": ast.literal_eval,
                                                     "cookie_second": ast.literal_eval
                                                     })

# %%
providers = ['squarespace', 'wix', 'weebly', 'jimdo', 'shopify',
             'bigcommerce', 'webnode', 'site123', 'wordpress',
             'medium-com', 'webflow', 'joomla']

site_stats = {}
for p in providers:
    mask = df['Host'].apply(lambda x: p in x)
    p_df = df[mask]
    site_stats[p] = len(p_df)

fig, ax = plt.subplots()
plt.bar(range(len(site_stats)), list(site_stats.values()), align='center')
plt.xticks(range(len(site_stats)), list(site_stats.keys()), rotation='vertical')
plt.show()

# %%
import math
for p in site_stats:
    print(p, math.floor((12-len(p))/6)*'\t'+'\t', site_stats[p])

# %%
import base64
import binascii

count = 0
for index, row in df.iterrows():
    if len(row['cookie_first']) != 0:
        cookie = row['cookie_first'].pop()
        for key, value in cookie.items():
            if key == 'value':
                try:
                    base64_bytes = value.encode('ascii')
                    message_bytes = base64.b64decode(base64_bytes)
                    message = message_bytes.decode('ascii')
                    print(key, '->', message)
                except binascii.Error:
                    print(key, '->', value, '*')
                except UnicodeDecodeError:
                    print(key, '->', value, '*')
            else:
                # print(key, '->', value)
                print('', end='')
        count+=1
    if count > 100:
        break

# %%
empty = {'cookie': None}
df[df['cookie_second'] == empty].count()
# Out:
# Website          64
# Host             64
# cookie_first     64
# Host checked     64
# click_found      64
# cookie_second    64
# dtype: int64

# %%
df[(df['cookie_second'] != empty) & (df['cookie_second'] != {})]
# Out:
#                     Website  \
# 25                wikia.com
# 62            wordpress.com
# 84               intuit.com
# 144           mailchimp.com
# 198               heavy.com
# ...                     ...
# 32878       embedsocial.com
# 32919  worldtravelguide.net
# 32938            timken.com
# 32992           brafton.com
# 33096        allmyfaves.com
#
#                                                     Host  \
# 25                                           [wordpress]
# 62                                           [wordpress]
# 84                                           [wordpress]
# 144                                          [wordpress]
# 198                                          [wordpress]
# ...                                                  ...
# 32878  [squarespace, wix, weebly, shopify, bigcommerc...
# 32919                                        [wordpress]
# 32938                                        [wordpress]
# ...

# %%
df['click_found'].sum()
# Out:
# 363

# %%
import chardet

for index, row in df.iterrows():
    if len(row['cookie_second']) > 0:
        print('-'*20)
        print(row['Website'])
        if (row['cookie_second'] == {}) | (row['cookie_second'] == {'cookie': None}):
            continue
        else:
            for c_num in range(len(row['cookie_second'])):
                for k, v in row['cookie_second'][c_num].items():
                    if k == 'name':
                        print(v, end=' = ')
                    if k == 'value':
                        v = str(v)
                        if '%' in v:
                            v = v.split('%')

                        print(v)
# Out:
# --------------------
# wikia.com
# tracking-opt-in-status = accepted
# tracking-opt-in-version = 2
# Geo = ['{', '22region', '22:', '22LI', '22', '2C', '22country', '22:', '22NL', '22', '2C', '22continent', '22:', '22EU', '22}']
# wikia_session_id = Pap1nVGJFq
# wikia_beacon_id = P2399flJiu
# --------------------
# wordpress.com
# sensitive_pixel_option = yes
# dcmsid = 1TzG8oPMviH75WZDD2UWnNb9PmZezaxg
# ccpa_applies = false
# country_code = NL
# landingpage_currency = EUR
# --------------------
# intuit.com
# ccpa = 1|1
# ivid = 28a17aea-69aa-4d22-af64-ebaecb98318f
# AKA_A2 = A
# --------------------
# mailchimp.com
# OptanonConsent = ['isIABGlobal=false&datestamp=Wed+Jul+01+2020+14', '3A17', '3A32+GMT', '2B0200+(Central+European+Summer+Time)&version=6.1.0&landingPath=NotLandingPage&groups=1', '3A1', '2C2', '3A1', '2C4', '3A1', '2C3', '3A1&hosts=&legInt=']
# OptanonAlertBoxClosed = 2020-07-01T12:17:32.569Z
# ...
